# %%
import pytesseract
import cv2

# %%
pytesseract.pytesseract.tesseract_cmd ="C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

# %%
image = cv2.imread("C:/Users/DELL/Desktop/Internship/Screenshot 2024-08-13 022044.png")
cv2.imshow("input", image)
cv2.waitKey(0)
# Out:
# -1

# %%
image = cv2.imread("C:/Users/DELL/Desktop/Internship/Screenshot 2024-08-13 022044.png")
img_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print(pytesseract.image_to_string(img_RGB))
# Out:
# Complex Sentence
#
# A complex sentence is a sentence
# with a simple sentence (complete
# sentence) and at least one
# incomplete sentence.

# %%
results = pytesseract.image_to_boxes(img_RGB)
ih, iw, ic = image.shape
for box in results.splitlines():
    box = box.split(' ')
    print(box)

    x, y, w, h = int(box[1]), int(box[2]), int(box[3]), int(box[4])
    cv2.rectangle(image, (x, ih-y), (w, ih-h), (0, 255, 0), 2)
    cv2.putText(image, box[0], (x, ih-h), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 0, 0), 1)
# Out:
# ['C', '60', '437', '92', '479', '0']
# ['o', '96', '437', '125', '468', '0']
# ['m', '131', '438', '172', '468', '0']
# ['p', '159', '428', '191', '481', '0']
# ['l', '180', '428', '207', '468', '0']
# ['e', '213', '437', '251', '481', '0']
# ['x', '255', '438', '285', '468', '0']
# ['S', '304', '437', '329', '479', '0']
# ['e', '333', '437', '357', '468', '0']
# ['n', '365', '438', '389', '468', '0']
# ['t', '394', '437', '412', '473', '0']
# ['e', '415', '437', '440', '468', '0']
# ['n', '447', '438', '471', '468', '0']
# ['c', '477', '437', '500', '468', '0']
# ['e', '504', '437', '529', '468', '0']
# ['A', '58', '242', '89', '276', '0']
# ['c', '116', '242', '135', '268', '0']
# ['o', '139', '242', '163', '268', '0']
# ['m', '170', '242', '204', '268', '0']
# ['p', '195', '233', '222', '278', '0']
# ['l', '213', '233', '247', '278', '0']
# ['e', '254', '242', '274', '268', '0']
# ['x', '279', '242', '302', '267', '0']
# ['s', '333', '242', '349', '268', '0']
# ['e', '355', '242', '376', '268', '0']
# ['n', '383', '242', '403', '268', '0']
# ['t', '409', '242', '423', '272', '0']
# ['e', '427', '242', '447', '268', '0']
# ['n', '455', '242', '475', '268', '0']
# ['c', '481', '242', '500', '268', '0']
# ['e', '505', '242', '525', '268', '0']
# ['i', '557', '242', '562', '276', '0']
# ['s', '569', '242', '586', '268', '0']
# ['a', '616', '242', '638', '268', '0']
# ['s', '667', '242', '684', '268', '0']
# ['e', '690', '242', '710', '268', '0']
# ['n', '717', '242', '737', '268', '0']
# ['t', '743', '242', '757', '272', '0']
# ['e', '761', '242', '781', '268', '0']
# ['n', '789', '242', '809', '268', '0']
# ['c', '815', '242', '835', '268', '0']
# ['e', '839', '242', '859', '268', '0']
# ['w', '58', '187', '92', '212', '0']
# ['i', '97', '187', '102', '221', '0']
# ['t', '108', '186', '122', '216', '0']
# ['h', '128', '187', '148', '223', '0']
# ['a', '183', '186', '206', '212', '0']
# ['s', '239', '186', '256', '212', '0']
# ['i', '264', '187', '268', '221', '0']
# ['m', '277', '187', '312', '212', '0']
# ['p', '320', '178', '343', '212', '0']
# ['l', '349', '187', '354', '223', '0']
# ['e', '361', '186', '381', '212', '0']
# ['s', '417', '186', '433', '212', '0']
# ['e', '439', '186', '459', '212', '0']
# ['n', '467', '187', '487', '212', '0']
# ['t', '493', '186', '507', '216', '0']
# ['e', '511', '186', '531', '212', '0']
# ['n', '539', '187', '559', '212', '0']
# ['c', '565', '186', '584', '212', '0']
# ['e', '589', '186', '609', '212', '0']
# ['(', '644', '181', '655', '222', '0']
# ['c', '659', '186', '678', '212', '0']
# ['o', '682', '186', '706', '212', '0']
# ['m', '713', '187', '747', '212', '0']
# ['p', '738', '178', '765', '223', '0']
# ['l', '756', '178', '778', '212', '0']
# ['e', '785', '186', '817', '223', '0']
# ['t', '821', '186', '835', '216', '0']
# ['e', '839', '186', '859', '212', '0']
# ['s', '61', '131', '78', '157', '0']
# ['e', '83', '131', '103', '157', '0']
# ['n', '111', '131', '131', '157', '0']
# ['t', '137', '131', '151', '161', '0']
# ['e', '155', '131', '175', '157', '0']
# ['n', '183', '131', '203', '157', '0']
# ['c', '210', '131', '228', '157', '0']
# ['e', '233', '125', '269', '167', '0']
# [')', '264', '125', '269', '167', '0']
# ['a', '343', '131', '365', '157', '0']
# ['n', '371', '131', '391', '157', '0']
# ['d', '397', '131', '420', '167', '0']
# ['a', '496', '131', '507', '161', '0']
# ['t', '496', '131', '534', '161', '0']
# ['l', '609', '131', '614', '167', '0']
# ['e', '621', '131', '641', '157', '0']
# ['a', '646', '131', '669', '157', '0']
# ['s', '673', '131', '690', '157', '0']
# ['t', '695', '131', '709', '161', '0']
# ['o', '783', '131', '806', '157', '0']
# ['n', '813', '131', '833', '157', '0']
# ['e', '840', '131', '860', '157', '0']
# ['i', '62', '76', '66', '110', '0']
# ['n', '75', '75', '121', '101', '0']
# ['c', '112', '67', '135', '112', '0']
# ['o', '126', '75', '149', '101', '0']
# ['m', '156', '76', '191', '101', '0']
# ['p', '184', '67', '207', '112', '0']
# ['l', '199', '67', '221', '101', '0']
# ['e', '228', '75', '260', '112', '0']
# ['t', '264', '75', '278', '105', '0']
# ['e', '283', '75', '303', '101', '0']
# ['s', '324', '75', '340', '101', '0']
# ['e', '347', '75', '367', '101', '0']
# ['n', '374', '76', '394', '101', '0']
# ['t', '400', '75', '414', '105', '0']
# ['e', '418', '75', '438', '101', '0']
# ['n', '446', '76', '466', '101', '0']
# ['c', '458', '75', '481', '105', '0']
# ['e', '473', '75', '492', '101', '0']
# ['.', '496', '75', '530', '101', '0']

# %%
  results = pytesseract.image_to_data(img_RGB)
  for id, line in enumerate(results.splitlines()):
 
      if id != 0:
          line = line.split()
          if len(line) == 12:
              x, y, w, h = int(line[6]), int(line[7]), int(line[8]), int(line[9])
              cv2.rectangle(image, (x, y), (w+x, h+y), (0, 255, 0), 2)
              cv2.putText(image, line[11], (x, y), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 0, 0), 2)

cv2.imshow("Input", image)
cv2.waitKey(0)
# Out:
# -1
